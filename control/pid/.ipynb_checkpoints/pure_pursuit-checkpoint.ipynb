# %% [markdown]
# <U>Pure-pursuit Control</U> is a path tracking algorithm that makes the robot to follow a given trajectory. It simply computes the angular velocity command that moves the robot from its current position to reach some look-ahead point on the given trajectory. The robot then moves the nearest look-ahead point on the path based on the current position of the robot until the last point of the path.
#
# Given the pose (position and orientation) of the robot as an input, the object can be used to calculate the linear and angular velocities commands for the robot.
#
# The robot’s pose is input as a pose and orientation (theta) list of points as [x y theta]. The theta value is the angular orientation of the robot measured counterclockwise in radians from the x-axis (robot currently at 0 radians).

# %% [markdown]
# <img src='./figs/coord.png' width='400'>
# <img src='./figs/lfc.png' width='400'>
# <img src='./figs/lfc2.png' width='400'>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %matplotlib qt

# %% [markdown]
# <img src='./figs/car.png' width='300'>

# %%
class mobile():
    def __init__(self, x=0., y=0., yaw=0., v=0., \
                       l=2.9, lfc=1., dt=0.1):
        """
        x, y: 2D position
        v: velocity
        yaw: orientation according to z-axis
        l: wheel base [m]
        lfc: look-ahead distance
        dt: [s]
        """
        self.x = x
        self.y = y
        self.yaw = yaw
        self.v = v
        self.l = l
        self.lfc = lfc
        self.dt = dt
        
    def update(self, a, delta):
        self.x += self.v*math.cos(self.yaw)*self.dt
        self.y += self.v*math.sin(self.yaw)*self.dt
        self.yaw += self.v/self.l*math.tan(delta)*self.dt
        self.v += a*self.dt

# %%
def get_idx(robot, x_ref, y_ref):
    """
    get nearest position index
    """
    dx = [robot.x - x_i for x_i in x_ref]
    dy = [robot.x - y_i for y_i in y_ref]
    d = [abs(math.sqrt(dx_i**2 + dy_i**2)) for (dx_i, dy_i) in zip(dx, dy)]
    idx = d.index(min(d))

    lfc_i = 0
    while robot.lfc > lfc_i and (idx + 1) < len(x_ref):
        dx = x_ref[idx + 1] - x_ref[idx]
        dy = y_ref[idx + 1] - y_ref[idx]
        lfc_i += math.sqrt(dx**2 + dy**2)
        idx += 1
    
    return idx

# %%
def pure_pursuit_control(robot, x_ref, y_ref, idx_ref):
    idx = get_idx(robot, x_ref, y_ref)
    
    if idx_ref >= idx:
        idx = idx_ref
    
    if idx < len(x_ref):
        tx = x_ref[idx]
        ty = y_ref[idx]
    else:
        tx = x_ref[-1]
        ty = y_ref[-1]
        idx = len(x_ref) - 1
        
    theta = math.atan2(ty - robot.y, tx - robot.x) - robot.yaw
    
    if robot.v < 0: # backward
        theta = math.pi - theta
        
    delta = math.atan2(2.0*robot.l*math.sin(theta)/robot.lfc, 1.0)
    
    return delta, idx

# %%
anim = True

# define reference track and velocity
x_ref = np.arange(0, 50, 0.1)
y_ref = [math.sin(i/5.0)*i/2.0 for i in x_ref]
v_ref = 10./3.6 # [m/s]

t_T = 100.
t = 0

x_0 = 0.
y_0 = -3.
yaw_0 = 0.
v_0 = 0.
robot = mobile(x=x_0, y=y_0, yaw=yaw_0, v=v_0)

# save trajectories
x_list, y_list, yaw_list, v_list = [], [], [], []
t_list = []
x_list.append(robot.x)
y_list.append(robot.y)
yaw_list.append(robot.yaw)
v_list.append(robot.v)
t_list.append(0.0)
idx_ref = get_idx(robot, x_ref, y_ref) 
    
Kp = 1.0
while t_T >= t and len(x_ref) > idx_ref:
    print('\r>> time: {:.3f}'.format(t), end='')
    a_i = Kp * (v_ref - robot.v)
    d_i, idx_ref = pure_pursuit_control(robot, x_ref, y_ref, idx_ref)
    
    robot.update(a_i, d_i)
    
    t += robot.dt
    
    x_list.append(robot.x)
    y_list.append(robot.y)
    yaw_list.append(robot.yaw)
    v_list.append(robot.v)
    t_list.append(0.0)    

    if anim:
        plt.cla()
        plt.plot(x_ref, y_ref, ".r", label="course")
        plt.plot(x_list, y_list, "-b", label="trajectory")
        plt.plot(x_ref[idx_ref], y_ref[idx_ref], "xg", label="target")
        plt.scatter(x_ref[idx_ref], y_ref[idx_ref], size=20)
        plt.axis("equal")
        plt.grid(True)
        plt.title("Speed[km/h]:" + str(robot.v * 3.6)[:4])
        plt.pause(0.001)
# Out:
# >> time: 12.500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in _draw_idle(self)
#     517             return
#     518         try:
# --> 519             self.draw()
#     520         except Exception:
#     521             # Uncaught exceptions are fatal for PyQt5, so catch them instead.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1183         renderer.open_group(__name__)
#    1184
# -> 1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1187                                                                 renderer)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     966         """
#     967         majorLocs = self.major.locator()
# --> 968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#     970         majorLabels = [self.major.formatter(val, i)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1393         while len(self.majorTicks) < numticks:
#    1394             # update the new tick label properties from the old
# -> 1395             tick = self._get_tick(major=True)
#    1396             self.majorTicks.append(tick)
#    1397             if self._gridOnMajor:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1816         else:
#    1817             tick_kw = self._minor_tick_kw
# -> 1818         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1819
#    1820     def _get_label(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     178         self.label1 = self._get_text1()
#     179         self.label = self.label1  # legacy name
# --> 180         self.label2 = self._get_text2()
#     181
#     182         self.gridOn = gridOn
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _get_text2(self)
#     456             color=self._labelcolor,
#     457             verticalalignment=vert,
# --> 458             horizontalalignment=horiz,
#     459             )
#     460         t.set_transform(trans)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/text.py in __init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, **kwargs)
#     150         """
#     151
# --> 152         Artist.__init__(self)
#     153         self._x, self._y = x, y
#     154
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in __init__(self)
#      81
#      82     def __init__(self):
# ---> 83         self._stale = True
#      84         self.stale_callback = None
#      85         self._axes = None
#
# KeyboardInterrupt:
# >> time: 13.300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in _draw_idle(self)
#     517             return
#     518         try:
# --> 519             self.draw()
#     520         except Exception:
#     521             # Uncaught exceptions are fatal for PyQt5, so catch them instead.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1188
#    1189         for tick in ticks_to_draw:
# -> 1190             tick.draw(renderer)
#    1191
#    1192         # scale up the axis label box to also find the neighbors, not
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer)
#     302
#     303         if self.label1On:
# --> 304             self.label1.draw(renderer)
#     305         if self.label2On:
#     306             self.label2.draw(renderer)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/text.py in draw(self, renderer)
#     714             posx = float(textobj.convert_xunits(textobj._x))
#     715             posy = float(textobj.convert_yunits(textobj._y))
# --> 716             posx, posy = trans.transform_point((posx, posy))
#     717             if not np.isfinite(posx) or not np.isfinite(posy):
#     718                 _log.warning("posx and posy should be finite values")
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/transforms.py in transform_point(self, point)
#    1509         if len(point) != self.input_dims:
#    1510             raise ValueError("The length of 'point' must be 'self.input_dims'")
# -> 1511         return self.transform(np.asarray([point]))[0]
#    1512
#    1513     def transform_path(self, path):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/transforms.py in transform(self, values)
#    1422
#    1423         # Transform the values
# -> 1424         res = self.transform_affine(self.transform_non_affine(values))
#    1425
#    1426         # Convert the result back to the shape of the input values.
#
# KeyboardInterrupt:
# >> time: 13.800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in _draw_idle(self)
#     517             return
#     518         try:
# --> 519             self.draw()
#     520         except Exception:
#     521             # Uncaught exceptions are fatal for PyQt5, so catch them instead.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1183         renderer.open_group(__name__)
#    1184
# -> 1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1187                                                                 renderer)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     966         """
#     967         majorLocs = self.major.locator()
# --> 968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#     970         majorLabels = [self.major.formatter(val, i)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1397             if self._gridOnMajor:
#    1398                 tick.gridOn = True
# -> 1399             self._copy_tick_props(self.majorTicks[0], tick)
#    1400
#    1401         return self.majorTicks[:numticks]
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _copy_tick_props(self, src, dest)
#    1354         if src is None or dest is None:
#    1355             return
# -> 1356         dest.label1.update_from(src.label1)
#    1357         dest.label2.update_from(src.label2)
#    1358
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/text.py in update_from(self, other)
#     273         self._horizontalalignment = other._horizontalalignment
#     274         self._fontproperties = other._fontproperties.copy()
# --> 275         self._rotation = other._rotation
#     276         self._picker = other._picker
#     277         self._linespacing = other._linespacing
#
# KeyboardInterrupt:
# >> time: 14.100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in _draw_idle(self)
#     517             return
#     518         try:
# --> 519             self.draw()
#     520         except Exception:
#     521             # Uncaught exceptions are fatal for PyQt5, so catch them instead.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/lines.py in draw(self, renderer)
#     769
#     770                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 771                 renderer.draw_path(gc, tpath, affine.frozen())
#     772                 gc.restore()
#     773
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     147         else:
#     148             try:
# --> 149                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     150             except OverflowError:
#     151                 raise OverflowError("Exceeded cell block limit (set "
#
# KeyboardInterrupt:
# >> time: 14.400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in _draw_idle(self)
#     517             return
#     518         try:
# --> 519             self.draw()
#     520         except Exception:
#     521             # Uncaught exceptions are fatal for PyQt5, so catch them instead.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1183         renderer.open_group(__name__)
#    1184
# -> 1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1187                                                                 renderer)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     966         """
#     967         majorLocs = self.major.locator()
# --> 968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#     970         majorLabels = [self.major.formatter(val, i)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1393         while len(self.majorTicks) < numticks:
#    1394             # update the new tick label properties from the old
# -> 1395             tick = self._get_tick(major=True)
#    1396             self.majorTicks.append(tick)
#    1397             if self._gridOnMajor:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1816         else:
#    1817             tick_kw = self._minor_tick_kw
# -> 1818         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1819
#    1820     def _get_label(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     172         self.apply_tickdir(tickdir)
#     173
# --> 174         self.tick1line = self._get_tick1line()
#     175         self.tick2line = self._get_tick2line()
#     176         self.gridline = self._get_gridline()
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     468                           linestyle='None', marker=self._tickmarkers[0],
#     469                           markersize=self._size,
# --> 470                           markeredgewidth=self._width, zorder=self._zorder)
#     471         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     472         self._set_artist_props(l)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     384         self._color = None
#     385         self.set_color(color)
# --> 386         self._marker = MarkerStyle(marker, fillstyle)
#     387
#     388         self._markevery = None
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     243         self._marker_function = None
#     244         self.set_fillstyle(fillstyle)
# --> 245         self.set_marker(marker)
#     246
#     247     def _recache(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     316
#     317         self._marker = marker
# --> 318         self._recache()
#     319
#     320     def get_path(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/markers.py in _recache(self)
#     256         self._capstyle = 'butt'
#     257         self._filled = True
# --> 258         self._marker_function()
#     259
#     260     def __bool__(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/markers.py in _set_tickdown(self)
#     772
#     773     def _set_tickdown(self):
# --> 774         self._transform = Affine2D().scale(1.0, -1.0)
#     775         self._snap_threshold = 1.0
#     776         self._filled = False
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/transforms.py in scale(self, sx, sy)
#    2040         scale_mtx = np.array(
#    2041             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 2042         self._mtx = np.dot(scale_mtx, self._mtx)
#    2043         self.invalidate()
#    2044         return self
#
# KeyboardInterrupt:
# >> time: 14.700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in _draw_idle(self)
#     517             return
#     518         try:
# --> 519             self.draw()
#     520         except Exception:
#     521             # Uncaught exceptions are fatal for PyQt5, so catch them instead.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1183         renderer.open_group(__name__)
#    1184
# -> 1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1187                                                                 renderer)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     966         """
#     967         majorLocs = self.major.locator()
# --> 968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#     970         majorLabels = [self.major.formatter(val, i)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1393         while len(self.majorTicks) < numticks:
#    1394             # update the new tick label properties from the old
# -> 1395             tick = self._get_tick(major=True)
#    1396             self.majorTicks.append(tick)
#    1397             if self._gridOnMajor:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1816         else:
#    1817             tick_kw = self._minor_tick_kw
# -> 1818         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1819
#    1820     def _get_label(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     157             else:
#     158                 zorder = mlines.Line2D.zorder
# --> 159         self._zorder = zorder
#     160
#     161         self._grid_color = (rcParams['grid.color']
#
# KeyboardInterrupt:
# >> time: 14.900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in _draw_idle(self)
#     517             return
#     518         try:
# --> 519             self.draw()
#     520         except Exception:
#     521             # Uncaught exceptions are fatal for PyQt5, so catch them instead.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/lines.py in draw(self, renderer)
#     836                 renderer.draw_markers(gc, marker_path, marker_trans,
#     837                                       subsampled, affine.frozen(),
# --> 838                                       fc_rgba)
#     839
#     840                 alt_marker_path = marker.get_alt_path()
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/transforms.py in __array__(self, *args, **kwargs)
#     271
#     272     def __array__(self, *args, **kwargs):
# --> 273         return self.get_points()
#     274
#     275     def is_unit(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/transforms.py in get_points(self)
#    1077             self._points = np.array([
#    1078                 [xs[0], ys[0]],
# -> 1079                 [xs[1], ys[1]]
#    1080             ])
#    1081
#
# KeyboardInterrupt:
# >> time: 15.200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_qt5.py in _draw_idle(self)
#     517             return
#     518         try:
# --> 519             self.draw()
#     520         except Exception:
#     521             # Uncaught exceptions are fatal for PyQt5, so catch them instead.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1183         renderer.open_group(__name__)
#    1184
# -> 1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1187                                                                 renderer)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     966         """
#     967         majorLocs = self.major.locator()
# --> 968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#     970         majorLabels = [self.major.formatter(val, i)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1393         while len(self.majorTicks) < numticks:
#    1394             # update the new tick label properties from the old
# -> 1395             tick = self._get_tick(major=True)
#    1396             self.majorTicks.append(tick)
#    1397             if self._gridOnMajor:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2192         else:
#    2193             tick_kw = self._minor_tick_kw
# -> 2194         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2195
#    2196     def _get_label(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     174         self.tick1line = self._get_tick1line()
#     175         self.tick2line = self._get_tick2line()
# --> 176         self.gridline = self._get_gridline()
#     177
#     178         self.label1 = self._get_text1()
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _get_gridline(self)
#     621                           alpha=self._grid_alpha,
#     622                           markersize=0,
# --> 623                           **self._grid_kw)
#     624         l.set_transform(self.axes.get_yaxis_transform(which='grid'))
#     625         l.get_path()._interpolation_steps = GRIDLINE_INTERPOLATION_STEPS
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     399         self._markerfacecoloralt = None
#     400
# --> 401         self.set_markerfacecolor(markerfacecolor)
#     402         self.set_markerfacecoloralt(markerfacecoloralt)
#     403         self.set_markeredgecolor(markeredgecolor)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/lines.py in set_markerfacecolor(self, fc)
#    1157         if fc is None:
#    1158             fc = 'auto'
# -> 1159         if np.any(self._markerfacecolor != fc):
#    1160             self.stale = True
#    1161         self._markerfacecolor = fc
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in any(a, axis, out, keepdims)
#    2012
#    2013     """
# -> 2014     arr = asanyarray(a)
#    2015     kwargs = {}
#    2016     if keepdims is not np._NoValue:
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/numpy/core/numeric.py in asanyarray(a, dtype, order)
#     493
#     494
# --> 495 def asanyarray(a, dtype=None, order=None):
#     496     """Convert the input to an ndarray, but pass ndarray subclasses through.
#     497
#
# KeyboardInterrupt:
# >> time: 15.500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-7a83532dfd01> in <module>
#      42
#      43     if anim:
# ---> 44         plt.cla()
#      45         plt.plot(x_ref, y_ref, ".r", label="course")
#      46         plt.plot(x_list, y_list, "-b", label="trajectory")
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/pyplot.py in cla()
#    2510 @docstring.copy_dedent(Axes.cla)
#    2511 def cla():
# -> 2512     return gca().cla()
#    2513
#    2514
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axes/_base.py in cla(self)
#     978
#     979         for name, spine in self.spines.items():
# --> 980             spine.cla()
#     981
#     982         self.ignore_existing_data_limits = True
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/spines.py in cla(self)
#     178         self._position = None  # clear position
#     179         if self.axis is not None:
# --> 180             self.axis.cla()
#     181
#     182     def is_frame_like(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in cla(self)
#     811                              rcParams['axes.grid.which'] in ('both', 'minor'))
#     812
# --> 813         self.reset_ticks()
#     814
#     815         self.converter = None
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in reset_ticks(self)
#     834             pass
#     835         try:
# --> 836             self.set_clip_path(self.axes.patch)
#     837         except AttributeError:
#     838             pass
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     923     def set_clip_path(self, clippath, transform=None):
#     924         artist.Artist.set_clip_path(self, clippath, transform)
# --> 925         for child in self.majorTicks + self.minorTicks:
#     926             child.set_clip_path(clippath, transform)
#     927         self.stale = True
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     675             if self._major:
#     676                 instance.majorTicks = []
# --> 677                 tick = instance._get_tick(major=True)
#     678                 instance.majorTicks.append(tick)
#     679                 return instance.majorTicks
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2192         else:
#    2193             tick_kw = self._minor_tick_kw
# -> 2194         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2195
#    2196     def _get_label(self):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     173
#     174         self.tick1line = self._get_tick1line()
# --> 175         self.tick2line = self._get_tick2line()
#     176         self.gridline = self._get_gridline()
#     177
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     607                           markersize=self._size,
#     608                           markeredgewidth=self._width,
# --> 609                           zorder=self._zorder)
#     610         l.set_transform(self.axes.get_yaxis_transform(which='tick2'))
#     611         self._set_artist_props(l)
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     408         # update kwargs before updating data to give the caller a
#     409         # chance to init axes (and hence unit support)
# --> 410         self.update(kwargs)
#     411         self.pickradius = pickradius
#     412         self.ind_offset = 0
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     911                 if not callable(func):
#     912                     raise AttributeError('Unknown property %s' % k)
# --> 913                 return func(v)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
#
# ~/.virtualenvs/p3/lib/python3.6/site-packages/matplotlib/artist.py in set_zorder(self, level)
#     956         if level is None:
#     957             level = self.__class__.zorder
# --> 958         self.zorder = level
#     959         self.pchanged()
#     960         self.stale = True
#
# KeyboardInterrupt:

# %%
assert
